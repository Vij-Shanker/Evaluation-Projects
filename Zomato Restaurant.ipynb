# %% [markdown]
# ### Project Description
# - Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best cuisines of every part of the world which lies in their budget. This analysis is also for those who want to find the value for money restaurants in various parts of the country for the cuisines.
#
# - Additionally, this analysis caters the needs of people who are striving to get the best cuisine of the country and which locality of that country serves that cuisines with maximum number of restaurants.
#
# **About Datasets:**
#
# - This problem statement contains two datasets- Zomato.csv and country_code.csv.
#
# - Country_code.csv contains two variables:
#     • Country code
#     • Country name
#
#     The collected data has been stored in the Comma Separated Value file Zomato.csv. Each restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
#     • Restaurant Id: Unique id of every restaurant across various cities of the world
#
#     • Restaurant Name: Name of the restaurant
#
#     • Country Code: Country in which restaurant is located
#
#     • City: City in which restaurant is located
#
#     • Address: Address of the restaurant
#
#     • Locality: Location in the city
#
#     • Locality Verbose: Detailed description of the locality
#
#     • Longitude: Longitude coordinate of the restaurant&#39;s location
#
#     • Latitude: Latitude coordinate of the restaurant&#39;s location
#
#     • Cuisines: Cuisines offered by the restaurant
#
#     • Average Cost for two: Cost for two people in different currencies ��
#
#     • Currency: Currency of the country
#
#     • Has Table booking: yes/no
#
#     • Has Online delivery: yes/ no
#
#     • Is delivering: yes/ no
#
#     • Switch to order menu: yes/no
#
#     • Price range: range of price of food
#
#     • Aggregate Rating: Average rating out of 5
#
#     • Rating color: depending upon the average rating color
#
#     • Rating text: text on the basis of rating of rating
#
#     • Votes: Number of ratings casted by people
#
# #### Problem statement : In this dataset predict 2 things –
# 1) Average Cost for two
# 2) Price range
#
#
#     Hint : Use pandas methods to combine all the datasets and then start working on this project.
#
# ### Dataset Link-
#
# •	https://github.com/FlipRoboTechnologies/ML_-Datasets/blob/main/Z_Restaurant/Country-Code.xlsx
#
# •	https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Z_Restaurant/zomato.csv

# %% [markdown]
# ### Read and understand dataset

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('F:\FlipRobo\Project Evaluation\Zomato')
df1=pd.read_csv('zomato.csv', encoding='latin1',na_values=["?"])
df2=pd.read_excel('Country-Code.xlsx')
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# #### Observation:
# - 'Country Code' is already present in dataset df1 sourced from file "zomato.csv" file.
#
# #### Next:
# - To map Country code against the Country using dataset df2 sourced from the file "Country-Code.xlsx".

# %%
# Get unique values from 'Country Code' and 'Country'
unique_values_column1 = df2['Country Code'].unique()
unique_values_column2 = df2['Country'].unique()

# Create a mapping dictionary from Column1 to Column2
mapping_dict = dict(zip(unique_values_column1, unique_values_column2))
df1['Country']=df1['Country Code'].map(mapping_dict)
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df2.shape
# Out:
# (15, 2)

# %% [markdown]
# #### Observation:
# In dataset df1
# - Rows = 9551
# - Columns = 21
#
# #### Next:
# - To perform exploratory data analysis

# %% [markdown]
# ### Exploratory data analysis
# ### (i) To explore data type of all the  variables

# %%
df1.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df1['Currency'].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(\x8c£)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
# Using exchange rate as on 14th May 2024
exchange_rates = {'Dollar($)': 1, 'Botswana Pula(P)': 0.074, 'Brazilian Real(R$)':0.19, 'Emirati Diram(AED)':0.27, 'Indian Rupees(Rs.)':0.012,'Indonesian Rupiah(IDR)':0.000062,'NewZealand($)':0.60,'Pounds(\x8c£)':1.26,'Qatari Rial(QR)':0.27,'Rand(R)':0.054 ,'Sri Lankan Rupee(LKR)':0.0033,'Turkish Lira(TL)':0.031}
df1['Average Cost for two_USD'] = df1.apply(lambda row: row['Average Cost for two'] * exchange_rates[row['Currency']], axis=1)

# %%
df1['Switch to order menu'].unique()
# Out:
# array(['No'], dtype=object)

# %% [markdown]
# #### Observation:
# - Variable 'Switch to order menu' has only one value
#
# #### Next
#
# - Dropping variable 'Switch to order menu'

# %%
df3=df1.drop(columns=['Average Cost for two', 'Currency','Restaurant ID', 'Restaurant Name','Rating color','City', 'Address', 'Locality', 'Locality Verbose','Rating text','Switch to order menu','Country Code'],inplace=False)
df3.columns
# Out:
# Index(['Longitude', 'Latitude', 'Cuisines', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Votes', 'Country', 'Average Cost for two_USD'],
#       dtype='object')

# %%
df3.select_dtypes('object').columns
# Out:
# Index(['Cuisines', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Country'],
#       dtype='object')

# %% [markdown]
# ### (ii) To explore missing values

# %%
df3.isnull().sum()
# Out:
# Longitude                   0
# Latitude                    0
# Cuisines                    9
# Has Table booking           0
# Has Online delivery         0
# Is delivering now           0
# Price range                 0
# Aggregate rating            0
# Votes                       0
# Country                     0
# Average Cost for two_USD    0
# dtype: int64

# %% [markdown]
# #### Observation:
# - Missing values in variable "Cuisines" = 9
#
# #### Next:
# - Variable "Cuisines" is categorical, so imputing the missing values by its mode

# %%
df3['Cuisines'] = df3['Cuisines'].fillna(df3['Cuisines'].mode()[0])
df3.isnull().sum()
# Out:
# Longitude                   0
# Latitude                    0
# Cuisines                    0
# Has Table booking           0
# Has Online delivery         0
# Is delivering now           0
# Price range                 0
# Aggregate rating            0
# Votes                       0
# Country                     0
# Average Cost for two_USD    0
# dtype: int64

# %%
df3['Aggregate rating'].unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 0. , 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8,
#        2.1, 2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
df3.dtypes
# Out:
# Longitude                   float64
# Latitude                    float64
# Cuisines                     object
# Has Table booking            object
# Has Online delivery          object
# Is delivering now            object
# Price range                   int64
# Aggregate rating            float64
# Votes                         int64
# Country                      object
# Average Cost for two_USD    float64
# dtype: object

# %% [markdown]
# ### (iii) To explore distribution of all the  variables

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Longitude                 9551 non-null   float64
#  1   Latitude                  9551 non-null   float64
#  2   Cuisines                  9551 non-null   object
#  3   Has Table booking         9551 non-null   object
#  4   Has Online delivery       9551 non-null   object
#  5   Is delivering now         9551 non-null   object
#  6   Price range               9551 non-null   int64
#  7   Aggregate rating          9551 non-null   float64
#  8   Votes                     9551 non-null   int64
#  9   Country                   9551 non-null   object
#  10  Average Cost for two_USD  9551 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 820.9+ KB

# %%
df3.select_dtypes(['int','float']).columns
# Out:
# Index(['Longitude', 'Latitude', 'Price range', 'Aggregate rating', 'Votes',
#        'Average Cost for two_USD'],
#       dtype='object')

# %% [markdown]
# #### Observation:
# - Discrete variables:'Country Code','Price range','Votes'
# - Continuous variables='Longitude', 'Latitude','Aggregate rating','Average Cost for two_USD'
#
# #### Next:
#
# - Visualizing the distribution of continuous and discrete variables

# %%
# Histogram for continous numerical variables.
Continuous=['Longitude', 'Latitude','Aggregate rating','Average Cost for two_USD']
df3[Continuous].hist(figsize=(10,10))
plt.show()

# %% [markdown]
# #### Observation:
# - Distribution of variables is highly skewed
#
# #### Next:
# - Calculating the skewness of variables

# %%
abs(df3[Continuous].skew())
# Out:
# Longitude                    2.807328
# Latitude                     3.081635
# Aggregate rating             0.954130
# Average Cost for two_USD    11.462902
# dtype: float64

# %% [markdown]
# #### Observation:
# - 'Average Cost for two_USD' has got the maximum skewness
#
# #### Next:
# - To check for outliers using boxplot

# %%
plt.figure(figsize=(12,20))
# for i in Numerical:
sns.boxplot(data=df3[Continuous])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #### Observation:
# - It is clearly visible that their a significant number of data lying beyond 1.5 times of inter quartile range(IQR). It means there are significant outliers.
#
# #### Next:
# - To check distribution of categorical variables usng count plot

# %%
# Define the number of bins and their ranges
num_bins = 8
bin_ranges1 = pd.cut(df3['Votes'], bins=num_bins)
# Add the discretized 'Votes' column to the DataFrame
df3['Votes_bin'] = bin_ranges1

# Select columns for plotting
columns_to_plot = df3.select_dtypes('object').columns.tolist() + ['Price range', 'Votes_bin']

# Plot each selected column
for column in columns_to_plot:
    plt.figure(figsize=(16, 20))
    if column == 'Votes_bin':
        sns.countplot(y=column, data=df3, order=df3['Votes_bin'].value_counts().index)  # Plot with order of bin counts
    else:
        sns.countplot(y=column, data=df3)
    plt.yticks(rotation=0)
    plt.show()

# Remove the added 'Votes_bin' column
df3.drop('Votes_bin', axis=1, inplace=True)

# %% [markdown]
# #### Observation:
# - 'Cuisines' has a large number of values
# - Variable "votes" which have been grouped into 8 bins and labelled as "Votes_bin" has significantly large number of values in the first bin(0-1366).
#
# #### Next:
#
# - To check for multicollinearity

# %% [markdown]
# ### (iv) Correlation Analysis:
#    - To compute and visualize pairwise correlations between numerical variables using heatmap.
#    - To identify highly correlated variables (correlation coefficient > 0.7 or < -0.7).

# %%
# Heatmap for correlation coefficient
plt.figure(figsize=(16,12))
sns.heatmap(round(abs(df3[df3.select_dtypes(['float','int']).columns].corr()),2),annot=True)
plt.show()

# %% [markdown]
# #### Observation:
# - There is no significant correlation between two variables
#
# #### Next:
# - To identify outlers

# %% [markdown]
# ### (v) Feature Engineering:
# ### Detecting outliers using z-score
# - z = (X-μ)/σ;  where, X = data point, μ = mean of the data, σ = standard deviation

# %% [markdown]
# - Listing outliers having z score > 3 in variables Longitude, Latitude, Aggregate rating and      Average Cost for two_USD

# %%
for i in ["Longitude", "Latitude", "Aggregate rating","Average Cost for two_USD"]:
    outlier=[]
    mean=df3[i].mean()
    std=df3[i].std()
    threshold=3
    for j in df3[i].values:
        if np.abs((j-mean)/std)>threshold:
            outlier.append(j)
    print(f'\nOutliers in {i}:\n',outlier)
# Out:
# Outliers in Longitude:
# ...

# %% [markdown]
# #### Observation:
# - There are no outliers in "Aggregate rating"
#
# #### Next:
# - Removing the outliers from the dataframe to reduce skewness.

# %%
for i in ["Longitude", "Latitude", "Aggregate rating","Average Cost for two_USD"]:
    outlier=[]
    mean=df3[i].mean()
    std=df3[i].std()
    threshold=3   # z score >3 are assumed outliers
    for j in df3[i].values:
        if np.abs((j-mean)/std)>threshold:
            outlier.append(j)
        df3 = df3[~df3[i].isin(outlier)]
df3
# Out:
#        Longitude   Latitude                         Cuisines  \
# 14    121.038110  14.598890                           Korean
# 18    121.045878  14.554360           Cafe, Korean, Desserts
# 462   103.859422   1.300404                           Bakery
# 464   103.814618   1.297826    Italian, French, Bakery, Cafe
# 466   103.860416   1.311551                             Cafe
# ...          ...        ...                              ...
# 9546   28.977392  41.022793                          Turkish
# 9547   29.041297  41.009847  World Cuisine, Patisserie, Cafe
# 9548   29.034640  41.055817           Italian, World Cuisine
# 9549   29.036019  41.057979                  Restaurant Cafe
# 9550   29.026016  40.984776                             Cafe
#
#      Has Table booking Has Online delivery Is delivering now  Price range  \
# 14                  No                  No                No            3
# 18                  No                  No                No            2
# ...

# %% [markdown]
# #### Observation:
# - After dropping the outliers, number of rows reduced to 8820
#
# #### Next:
# - Checking skewness after dropping the outliers

# %%
abs(df3[["Longitude", "Latitude", "Aggregate rating","Average Cost for two_USD"]].skew())
# Out:
# Longitude                   3.368868
# Latitude                    2.507214
# Aggregate rating            0.893040
# Average Cost for two_USD    2.911658
# dtype: float64

# %% [markdown]
# #### Observation:
# - Clearly skewness of the variables has reduced significantly, particularly of variable "Average Cost for two_USD"
# - However, there is still considerable skewness present.
#
#
# #### Next:
# - Skewness present even after dropping the outliers, will be taken care of by tree based models.
# - To perform transformation of categorical variables to numerical using suitable encoding techniques

# %% [markdown]
# #### Variable: 'Cuisines'
# - To perform clustering-based encoding of categorical variable "Cuisines" for a large number of values in it

# %%
# Perform one-hot encoding to create binary features for each cuisine

one_hot_encoded = pd.get_dummies(df3['Cuisines'], prefix='Cuisine')
one_hot_encoded
# Out:
#       Cuisine_Afghani  Cuisine_Afghani, Mughlai, Chinese  \
# 14                  0                                  0
# 18                  0                                  0
# 462                 0                                  0
# 464                 0                                  0
# 466                 0                                  0
# ...               ...                                ...
# 9546                0                                  0
# 9547                0                                  0
# 9548                0                                  0
# 9549                0                                  0
# 9550                0                                  0
#
#       Cuisine_Afghani, North Indian  \
# 14                                0
# 18                                0
# 462                               0
# 464                               0
# 466                               0
# ...                             ...
# ...

# %% [markdown]
# #### Observation:
# - All the cuisines have been encoded using one hot encoding creating a very large number of varibles.
#
# #### Next:
# - To create cluster of similar cuisines using K means clustering

# %%
# To find optimum number of clusters using "Elbow method"

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []
for k in range(1, 400):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(one_hot_encoded)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 400), inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# #### Observation:
# - After 250 the the rate of decrease of inertia significantly reduces
#
# #### Next:
# - Creating 250 clusters using K-means clustering

# %%
# Perform clustering (e.g., using K-means) to group similar cuisines
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=250, random_state=42)
clusters = kmeans.fit_predict(one_hot_encoded)

# Assign cluster labels to each city
df3['Cuisines_Label'] = clusters
df3
# Out:
#        Longitude   Latitude                         Cuisines  \
# 14    121.038110  14.598890                           Korean
# 18    121.045878  14.554360           Cafe, Korean, Desserts
# 462   103.859422   1.300404                           Bakery
# 464   103.814618   1.297826    Italian, French, Bakery, Cafe
# 466   103.860416   1.311551                             Cafe
# ...          ...        ...                              ...
# 9546   28.977392  41.022793                          Turkish
# 9547   29.041297  41.009847  World Cuisine, Patisserie, Cafe
# 9548   29.034640  41.055817           Italian, World Cuisine
# 9549   29.036019  41.057979                  Restaurant Cafe
# 9550   29.026016  40.984776                             Cafe
#
#      Has Table booking Has Online delivery Is delivering now  Price range  \
# 14                  No                  No                No            3
# 18                  No                  No                No            2
# ...

# %%
df3.groupby('Cuisines_Label')['Cuisines'].sum()
# Out:
# Cuisines_Label
# 0      Cafe, Korean, DessertsItalian, French, Bakery,...
# 1      North IndianNorth IndianNorth IndianNorth Indi...
# 2      North Indian, ChineseNorth Indian, ChineseNort...
# 3      CafeCafeCafeCafeCafeCafeCafeCafeCafeCafeCafeCa...
# 4      Fast FoodFast FoodFast FoodFast FoodFast FoodF...
#                              ...
# 245    Mexican, American, Tex-Mex, BurgerMexican, Ame...
# 246    Fast Food, American, ItalianFast Food, America...
# 247    South Indian, Chinese, Fast FoodSouth Indian, ...
# 248    North Indian, Asian, ContinentalNorth Indian, ...
# 249    Street Food, Chinese, North IndianStreet Food,...
# Name: Cuisines, Length: 250, dtype: object

# %% [markdown]
# #### Observation:
# - 250 clusters of 1489 cuisines created
#
# #### Next:
# - Replacing variable 'Cuisines' by 'Cuisines_Label'

# %%
df4=df3.drop(columns='Cuisines',inplace=False)
df4.columns
# Out:
# Index(['Longitude', 'Latitude', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Price range', 'Aggregate rating', 'Votes',
#        'Country', 'Average Cost for two_USD', 'Cuisines_Label'],
#       dtype='object')

# %% [markdown]
# #### Next:
# - Using dummy encoding for variables: 'Has Table booking', 'Has Online delivery', 'Is delivering now'

# %%
df4_encoded=pd.get_dummies(df4[['Has Table booking', 'Has Online delivery', 'Is delivering now']],drop_first=True)
df4_encoded
# Out:
#       Has Table booking_Yes  Has Online delivery_Yes  Is delivering now_Yes
# 14                        0                        0                      0
# 18                        0                        0                      0
# 462                       0                        0                      0
# 464                       0                        0                      0
# 466                       0                        0                      0
# ...                     ...                      ...                    ...
# 9546                      0                        0                      0
# 9547                      0                        0                      0
# 9548                      0                        0                      0
# 9549                      0                        0                      0
# 9550                      0                        0                      0
#
# [8820 rows x 3 columns]

# %% [markdown]
# #### Next:
# - Concatenating this encoded values with the rest of the datafarme in df4

# %%
# Drop columns from df4 and store the result in df5
df5 = df4.drop(columns=['Has Table booking', 'Has Online delivery', 'Is delivering now'], inplace=False)

df5.reset_index(inplace=True) # Reset index of df5

df4_encoded.reset_index(inplace=True) # Reset index of df4_encoded

df6 = pd.concat([df5, df4_encoded], axis=1) # Concatenate df5 and df4_encoded along the columns axis

df6.reset_index(drop=True, inplace=True) # Reset index of df6

df6.set_index('Country', inplace=True)  # Set 'Country' column as the index of df6

df6.head()
# Out:
#              index   Longitude   Latitude  Price range  Aggregate rating  \
# Country
# Phillipines     14  121.038110  14.598890            3               4.3
# Phillipines     18  121.045878  14.554360            2               4.5
# Singapore      462  103.859422   1.300404            2               4.2
# Singapore      464  103.814618   1.297826            3               3.2
# Singapore      466  103.860416   1.311551            3               3.7
#
#              Votes  Average Cost for two_USD  Cuisines_Label  index  \
# Country
# Phillipines    223                      51.8             185     14
# Phillipines    118                      44.4               0     18
# Singapore       29                      20.0              14    462
# Singapore       29                      50.0               0    464
# Singapore       33                      40.0               3    466
#
#              Has Table booking_Yes  Has Online delivery_Yes  \
# Country
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8820 entries, Phillipines to Turkey
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     8820 non-null   int64
#  1   Longitude                 8820 non-null   float64
#  2   Latitude                  8820 non-null   float64
#  3   Price range               8820 non-null   int64
#  4   Aggregate rating          8820 non-null   float64
#  5   Votes                     8820 non-null   int64
#  6   Average Cost for two_USD  8820 non-null   float64
#  7   Cuisines_Label            8820 non-null   int32
#  8   index                     8820 non-null   int64
#  9   Has Table booking_Yes     8820 non-null   uint8
#  10  Has Online delivery_Yes   8820 non-null   uint8
#  11  Is delivering now_Yes     8820 non-null   uint8
# dtypes: float64(4), int32(1), int64(4), uint8(3)
# memory usage: 680.4+ KB

# %% [markdown]
# #### Obesrvation:
# - All the variables are now of numerical data type.
# - There are no null or missing values
#
# #### Next:
# - Checking the scale of the variables

# %%
df6.describe()
# Out:
#              index    Longitude     Latitude  Price range  Aggregate rating  \
# count  8820.000000  8820.000000  8820.000000  8820.000000       8820.000000
# mean   4990.549660    72.247434    26.475502     1.738549          2.553798
# std    2556.047348    19.136857     7.536670     0.856205          1.514355
# min      14.000000    -3.208363    -6.887058     1.000000          0.000000
# 25%    2777.750000    77.095391    28.486994     1.000000          2.300000
# 50%    4988.500000    77.201246    28.569516     2.000000          3.100000
# 75%    7193.250000    77.285570    28.638775     2.000000          3.600000
# max    9550.000000   174.779441    55.976644     4.000000          4.900000
#
#               Votes  Average Cost for two_USD  Cuisines_Label        index  \
# count   8820.000000               8820.000000     8820.000000  8820.000000
# mean     141.021429                  7.691813       28.053741  4990.549660
# ...

# %% [markdown]
# #### Observation
# - Variables have different range of values
#
# #### Next:
# - Scaling the dataframe using min max scaler

# %% [markdown]
# ### i) To predict: Average Cost for two

# %%
# Segregating the independent variables from the dependent variable "Average Cost for two"
X1=df6.drop(columns='Average Cost for two_USD',inplace=False)
y=df6['Average Cost for two_USD']

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X2=scale.fit_transform(X1)
X3=pd.DataFrame(X2,columns=X1.columns)
X3.describe()
# Out:
#              index    Longitude     Latitude  Price range  Aggregate rating  \
# count  8820.000000  8820.000000  8820.000000  8820.000000       8820.000000
# mean      0.521870     0.423938     0.530713     0.246183          0.521183
# std       0.268042     0.107518     0.119889     0.285402          0.309052
# min       0.000000     0.000000     0.000000     0.000000          0.000000
# 25%       0.289823     0.451176     0.562710     0.000000          0.469388
# 50%       0.521655     0.451770     0.564023     0.333333          0.632653
# 75%       0.752858     0.452244     0.565125     0.333333          0.734694
# max       1.000000     1.000000     1.000000     1.000000          1.000000
#
#              Votes  Cuisines_Label        index  Has Table booking_Yes  \
# count  8820.000000     8820.000000  8820.000000            8820.000000
# mean      0.012898        0.112666     0.521870               0.125850
# ...

# %% [markdown]
# #### Observation:
# - All the variables have been scaled between 0 and 1.
#
# #### Next:
# - To build the model

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,make_scorer
from sklearn.model_selection import cross_val_score,GridSearchCV

# %% [markdown]
# #### Random state: To estimate the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
r2_max=0
r_state=0
RF=RandomForestRegressor()
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=i)
    
    model_RF=RF.fit(X_train,y_train)
    y_pred_RF=model_RF.predict(X_test)
    r2_RF=r2_score(y_test,y_pred_RF)
    if r2_RF>r2_max:
        r2_max=r2_RF
        r_state=i
print(f'Best r2 score:', round(r2_max,3))
print(f'Random state: {r_state}')
# Out:
# Best r2 score: 0.914
# Random state: 268

# %% [markdown]
# ### Random Forest Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
RF=RandomForestRegressor()
model_RF1=RF.fit(X_train,y_train)
y_pred=model_RF1.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(RF,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.912
# Mean absolute error: 1.34
# Mean square error: 4.845
# Cross validation score: 0.877

# %% [markdown]
# ### Gradient Boosting Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
GB=GradientBoostingRegressor()
model_GB=GB.fit(X_train,y_train)
y_pred=model_GB.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(GB,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.902
# Mean absolute error: 1.449
# Mean square error: 5.391
# Cross validation score: 0.879

# %% [markdown]
# ### Adaboost Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
AR=AdaBoostRegressor()
model_AR=AR.fit(X_train,y_train)
y_pred=model_AR.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(AR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.792
# Mean absolute error: 2.304
# Mean square error: 11.431
# Cross validation score: 0.707

# %% [markdown]
# ### Bagging Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
BR=BaggingRegressor()
model_BR=BR.fit(X_train,y_train)
y_pred=model_BR.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(BR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.896
# Mean absolute error: 1.404
# Mean square error: 5.734
# Cross validation score: 0.871

# %% [markdown]
# ### K Neighbors Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
KN=KNeighborsRegressor()
model_KN=KN.fit(X_train,y_train)
y_pred=model_KN.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(KN,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.835
# Mean absolute error: 1.671
# Mean square error: 9.092
# Cross validation score: 0.811

# %% [markdown]
# ### Linear Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
LR=LinearRegression()
model_LR=LR.fit(X_train,y_train)
y_pred=model_LR.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(LR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.716
# Mean absolute error: 2.23
# Mean square error: 15.637
# Cross validation score: 0.711

# %% [markdown]
# ### Ridge Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
RR=Ridge()
model_RR=RR.fit(X_train,y_train)
y_pred=model_RR.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(RR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.715
# Mean absolute error: 2.23
# Mean square error: 15.689
# Cross validation score: 0.711

# %% [markdown]
# ### Lasso Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X3,y,test_size=0.3,random_state=r_state)
LaR=Lasso()
model_LaR=LaR.fit(X_train,y_train)
y_pred=model_LaR.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(LaR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.417
# Mean absolute error: 3.1
# Mean square error: 32.078
# Cross validation score: 0.436

# %% [markdown]
# #### Observation:
# - r2 scores is highest for "Random Forest Regression".
#
# #### Next:
# - Using "Random Forest Regression" for hyperparameter tuning to explore the possibilities to increase its accuracy further.

# %% [markdown]
# ### To check the current values of hyperparameters

# %%
from pprint import pprint
print('Parameters currently in use:\n')
pprint(RF.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Define the hyperparameters

hyp = {
    'bootstrap': [True],
    'ccp_alpha': [0.0],
    'criterion': ['squared_error'],
    'max_depth': [2, 6, 10, 14, 18, 20, 22, 24],
    'max_features': ['auto'],
    'max_leaf_nodes': [None],
    'max_samples': [None],
    'min_impurity_decrease': [0.0],
    'min_samples_leaf': [1],
    'min_samples_split': [2, 3, 5, 10],
    'min_weight_fraction_leaf': [0.0],
    'n_estimators': [100, 200, 300],
    'n_jobs': [-1],
    'oob_score': [False],
    'random_state': [r_state],
    'verbose': [0],
    'warm_start': [False]
}

# Define your Random Forest regressor
RF = RandomForestRegressor()

# Perform GridSearchCV
grid_search = GridSearchCV(RF, param_grid=hyp)
grid_search.fit(X_train, y_train)

# Print the best parameters, estimators, and score
print("Best parameters:", grid_search.best_params_)
print("Best estimator:", grid_search.best_estimator_)
print("Best score:", round(grid_search.best_score_,3))
# Out:
# Best parameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 14, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 3, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 300, 'n_jobs': -1, 'oob_score': False, 'random_state': 268, 'verbose': 0, 'warm_start': False}
# Best estimator: RandomForestRegressor(max_depth=14, min_samples_split=3, n_estimators=300,
#                       n_jobs=-1, random_state=268)
# Best score: 0.879

# %% [markdown]
# #### Observation:
#
# - Hyperparameter tuned Random forest regression model does not do better than its default Random forest regression model.
#
# #### Next:
#
# - Saving the default Random forest regression model.

# %% [markdown]
# ### Saving the final model: default Random forest regression
# - i) To predict: Average Cost for two

# %%
import pickle
with open('zomato','wb') as f:
    pickle.dump(model_RF1,f)

# %% [markdown]
# ### Loading the saved model

# %%
with open('zomato','rb') as f:
    zm=pickle.load(f)
round(zm.score(X_test,y_test),3)
# Out:
# 0.912

# %% [markdown]
# ### ii) To predict: Price range

# %%
# Segregating the independent variables from the dependent variable "Price range"
X_price_range=df6.drop(columns='Price range',inplace=False)
y1=df6['Price range']

# %% [markdown]
# #### Next:
# - Scaling the variables

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
X4=scale.fit_transform(X_price_range)
X5=pd.DataFrame(X4,columns=X_price_range.columns)
X5.describe()
# Out:
#              index    Longitude     Latitude  Aggregate rating        Votes  \
# count  8820.000000  8820.000000  8820.000000       8820.000000  8820.000000
# mean      0.521870     0.423938     0.530713          0.521183     0.012898
# std       0.268042     0.107518     0.119889          0.309052     0.039155
# min       0.000000     0.000000     0.000000          0.000000     0.000000
# 25%       0.289823     0.451176     0.562710          0.469388     0.000366
# 50%       0.521655     0.451770     0.564023          0.632653     0.002378
# 75%       0.752858     0.452244     0.565125          0.734694     0.009603
# max       1.000000     1.000000     1.000000          1.000000     1.000000
#
#        Average Cost for two_USD  Cuisines_Label        index  \
# count               8820.000000     8820.000000  8820.000000
# mean                   0.135658        0.112666     0.521870
# std                    0.128965        0.191253     0.268042
# ...

# %% [markdown]
# #### Observation:
# - All the variables have been scaled between 0 and 1.
#
# #### Next:
# - To build the model: ii) To predict: Price range

# %% [markdown]
# #### Random state:
# - To find the random state for maximum r2 score

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
r2_max=0
r_state=0
RF=RandomForestRegressor()
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=i)
    
    model_RF2=RF.fit(X_train,y_train)
    y_pred_RF=model_RF2.predict(X_test)
    r2_RF=r2_score(y_test,y_pred_RF)
    if r2_RF>r2_max:
        r2_max=r2_RF
        r_state=i
print(f'Best r2 score:', round(r2_max,3))
print(f'Random state: {r_state}')
# Out:
# Best r2 score: 0.989
# Random state: 787

# %% [markdown]
# ### Random Forest Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
RF=RandomForestRegressor()
model_RF3=RF.fit(X_train,y_train)
y_pred=model_RF3.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(RF,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.988
# Mean absolute error: 0.018
# Mean square error: 0.008
# Cross validation score: 0.982

# %% [markdown]
# ### Gradient Boosting Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
GB=GradientBoostingRegressor()
model_GB2=GB.fit(X_train,y_train)
y_pred=model_GB2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(GB,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.982
# Mean absolute error: 0.04
# Mean square error: 0.013
# Cross validation score: 0.976

# %% [markdown]
# ### Adaboost Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
AR=AdaBoostRegressor()
model_AR2=AR.fit(X_train,y_train)
y_pred=model_AR2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(AR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.892
# Mean absolute error: 0.253
# Mean square error: 0.077
# Cross validation score: 0.872

# %% [markdown]
# ### Bagging Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
BR=BaggingRegressor()
model_BR2=BR.fit(X_train,y_train)
y_pred=model_BR2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(BR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.987
# Mean absolute error: 0.019
# Mean square error: 0.009
# Cross validation score: 0.979

# %% [markdown]
# ### K Neighbors Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
KN=KNeighborsRegressor()
model_KN2=KN.fit(X_train,y_train)
y_pred=model_KN2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(KN,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.828
# Mean absolute error: 0.216
# Mean square error: 0.122
# Cross validation score: 0.811

# %% [markdown]
# ### Linear Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
LR=LinearRegression()
model_LR2=LR.fit(X_train,y_train)
y_pred=model_LR2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(LR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.731
# Mean absolute error: 0.349
# Mean square error: 0.192
# Cross validation score: 0.712

# %% [markdown]
# ### Ridge Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
RR=Ridge()
model_RR2=RR.fit(X_train,y_train)
y_pred=model_RR2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(RR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: 0.73
# Mean absolute error: 0.351
# Mean square error: 0.192
# Cross validation score: 0.712

# %% [markdown]
# ### Lasso Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X5,y1,test_size=0.3,random_state=r_state)
LaR=Lasso()
model_LaR2=LaR.fit(X_train,y_train)
y_pred=model_LaR2.predict(X_test)
r2=r2_score(y_test,y_pred)
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
cv_score=cross_val_score(LaR,X_train,y_train,cv=10).mean()  # performing 10 folds cross validation
print('r2 score:', round(r2,3))
print('Mean absolute error:', round(MAE,3))
print('Mean square error:',round(MSE,3))
print('Cross validation score:',round(cv_score,3))
# Out:
# r2 score: -0.001
# Mean absolute error: 0.711
# Mean square error: 0.713
# Cross validation score: -0.001

# %% [markdown]
# #### Observation:
# - r2 scores is highest for "Random Forest Regression".
#
# #### Next:
# - No need to go for hyperparamter tuning as r2 score of "Random Forest Regression" model is very high, which shows that the default Random forest model is very accurate. So saving the Random forest model.

# %% [markdown]
# ### Saving the final model: default Random forest regression
# - ii) To predict: Price range

# %%
import pickle
with open('zomato_2','wb') as f:
    pickle.dump(model_RF3,f)

# %% [markdown]
# ### Loading the saved model

# %%
with open('zomato_2','rb') as f:
    zm_2=pickle.load(f)
round(zm_2.score(X_test,y_test),3)
# Out:
# 0.988
